# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression, Lasso, LassoCV

from sklearn import linear_model
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

import xgboost as xgb

from copy import deepcopy

sns.set()
# %matplotlib inline

# %%
data_df = pd.read_csv('cleaned_data.csv')
print(data_df.shape)
data_df.head()
# Out:
# (2970, 78)
#      Country  Year  Top_1  Tax_Rev_to_GDP  Individual_Spending_Rate  \
# 0  Argentina  1965    NaN             NaN                       NaN
# 1  Argentina  1966    NaN             NaN                       NaN
# 2  Argentina  1967    NaN             NaN                       NaN
# 3  Argentina  1968    NaN             NaN                       NaN
# 4  Argentina  1969    NaN             NaN                       NaN
#
#    Society_Spending_Rate  Top_Rate  GDP_growth  1100  1110 ...   AC  AD  AE  \
# 0                    NaN       NaN   10.569433   NaN   NaN ...  NaN NaN NaN
# 1                    NaN       NaN   -0.659726   NaN   NaN ...  NaN NaN NaN
# 2                    NaN       NaN    3.191997   NaN   NaN ...  NaN NaN NaN
# 3                    NaN       NaN    4.822501   NaN   NaN ...  NaN NaN NaN
# 4                    NaN       NaN    9.679526   NaN   NaN ...  NaN NaN NaN
#
#    AF  AG  AH  AI  AJ  AK  CUS
# 0 NaN NaN NaN NaN NaN NaN  NaN
# ...

# %%
data_df_clean = data_df.dropna()
data_df_clean.reset_index(drop=True, inplace=True)

# %%
data_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 78 columns):
# Country                     289 non-null object
# Year                        289 non-null int64
# Top_1                       289 non-null float64
# Tax_Rev_to_GDP              289 non-null float64
# Individual_Spending_Rate    289 non-null float64
# Society_Spending_Rate       289 non-null float64
# Top_Rate                    289 non-null float64
# GDP_growth                  289 non-null float64
# 1100                        289 non-null float64
# 1110                        289 non-null float64
# 1120                        289 non-null float64
# 1200                        289 non-null float64
# 1210                        289 non-null float64
# 1220                        289 non-null float64
# 1300                        289 non-null float64
# 2100                        289 non-null float64
# 2110                        289 non-null float64
# ...

# %%
data_df_clean.Country.unique()
# Out:
# array(['Australia', 'Canada', 'Czech Republic', 'Denmark', 'Finland',
#        'France', 'Germany', 'Hungary', 'Ireland', 'Italy', 'Japan',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Spain', 'Sweden', 'Switzerland', 'Turkey', 'United States',
#        'United Kingdom'], dtype=object)

# %%
X = data_df_clean.drop(['Country', 'Year', '1100', 'Top_1', '6000'], axis=1)
X.head()
# Out:
#    Tax_Rev_to_GDP  Individual_Spending_Rate  Society_Spending_Rate  Top_Rate  \
# 0          30.377                 10.687945               6.890812      48.5
# 1          28.890                 10.638735               7.065841      48.5
# 2          29.739                 10.605550               6.817096      48.5
# 3          29.926                 10.742314               6.580981      48.5
# 4          30.258                 10.917760               6.653405      48.5
#
#    GDP_growth    1110  1120   1200   1210  1220 ...    AC   AD     AE   AF  \
# 0    3.943189  11.471   0.0  6.152  6.152   0.0 ...   0.0  0.0  0.025  0.0
# 1    1.933106  11.915   0.0  4.349  4.349   0.0 ...   0.0  0.0  0.007  0.0
# 2    4.003022  11.773   0.0  4.949  4.949   0.0 ...   0.0  0.0  0.009  0.0
# 3    2.985745  11.891   0.0  4.960  4.960   0.0 ...   0.0  0.0  0.016  0.0
# 4    4.001106  12.143   0.0  5.468  5.468   0.0 ...   0.0  0.0  0.022  0.0
#
#     AG   AH      AI   AJ      AK  CUS
# ...

# %%
X.tail()
# Out:
#      Tax_Rev_to_GDP  Individual_Spending_Rate  Society_Spending_Rate  \
# 284          32.592                 13.353168               5.718104
# 285          33.514                 12.982610               6.144255
# 286          32.755                 12.872451               6.014677
# 287          32.574                 12.614323               5.978749
# 288          32.176                 12.524406               6.063428
#
#      Top_Rate  GDP_growth   1110   1120   1200   1210   1220  ...       AC  \
# 284      50.0    1.694547  9.190  0.160  2.899  2.814  0.085  ...    0.301
# 285      50.0    1.452624  9.172  0.221  2.934  2.879  0.055  ...    0.300
# 286      50.0    1.481330  8.744  0.259  2.691  2.610  0.081  ...    0.318
# 287      45.0    2.052389  8.776  0.224  2.585  2.452  0.133  ...    0.334
# 288      45.0    3.054251  8.570  0.215  2.502  2.347  0.155  ...    0.353
#
#       AD     AE   AF     AG   AH      AI     AJ      AK    CUS
# ...

# %%
y = data_df_clean.Top_1

# %%
y = y*100
# Out:
# 0       8.210000
# 1       7.570000
# 2       7.930000
# 3       8.120000
# 4       8.420000
# 5       8.720000
# 6       9.510000
# 7       9.110000
# 8       8.080000
# 9       8.370000
# 10      8.550000
# 11      8.220000
# 12      8.520000
# 13      9.040000
# 14      8.980000
# 15      9.100000
# 16     14.621724
# 17     13.845496
# 18     13.346314
# 19     13.228601
# 20     13.968232
# 21     14.728966
# 22     15.426445
# 23     15.631597
# 24     14.377438
# 25     13.298443
# 26     13.623251
# 27      8.182738
# 28      8.187382
# 29      8.191911
#          ...
# 259    18.266000
# 260    17.268001
# 261    17.058000
# 262    17.202000
# 263    18.322000
# 264    19.372000
# 265    20.100001
# 266    19.867000
# 267    19.520000
# 268    18.540999
# 269    19.800000
# 270    19.599999
# 271    20.779000
# 272    19.592001
# 273    20.199999
# 274    13.508713
# 275    13.386109
# 276    13.025820
# 277    13.238943
# 278    13.300554
# 279    14.223754
# ...

# %% [markdown]
# ### Modeling

# %%
years = data_df_clean.Year
train_size = int(len(years) * .7)
test_size = len(years) - train_size
print(len(years), train_size, test_size)
# Out:
# 289 202 87

# %%
lr = LinearRegression()

# Split the data into training and test sets
X_train, y_train = X.loc[0:train_size, :] , y.loc[0:train_size]
X_test, y_test = X.loc[train_size:train_size+test_size, :] , y.loc[train_size:train_size+test_size]
# Fit the model against the training data
lr.fit(X_train, y_train)
# Evaluate the model against the testing data
lr.score(X_test, y_test)
# Out:
# /Users/bradpanzarella/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# -3.4578312480931466

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Fit the model against the training data
lr.fit(X_train, y_train)
# Evaluate the model against the testing data
lr.score(X_test, y_test)
# Out:
# -0.5589481750443901

# %% [markdown]
# ### Lasso

# %%
lasso = linear_model.Lasso(alpha=.0000001, max_iter=100000)

lasso.fit(X_train, y_train)
# Evaluate the model against the testing data
print(lasso.score(X_test, y_test))

test_pred = lasso.predict(X_test)
print(mean_squared_error(y_test, test_pred)  *10)
# Out:
# -0.2905884125924685
# 124.60894983161938
# /Users/bradpanzarella/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# ### Try With Trimmed Data

# %%
data_df_trimmed = pd.read_csv('trimmed_cleaned_data.csv')
print(data_df_trimmed.shape)
data_df_trimmed.head()
# Out:
# (2970, 29)
#      Country  Year  Top_1  Tax_Rev_to_GDP  Individual_Spending_Rate  \
# 0  Argentina  1965    NaN             NaN                       NaN
# 1  Argentina  1966    NaN             NaN                       NaN
# 2  Argentina  1967    NaN             NaN                       NaN
# 3  Argentina  1968    NaN             NaN                       NaN
# 4  Argentina  1969    NaN             NaN                       NaN
#
#    Society_Spending_Rate  Top_Rate  GDP_growth  1100  1200  ...   4500  4600  \
# 0                    NaN       NaN   10.569433   NaN   NaN  ...    NaN   NaN
# 1                    NaN       NaN   -0.659726   NaN   NaN  ...    NaN   NaN
# 2                    NaN       NaN    3.191997   NaN   NaN  ...    NaN   NaN
# 3                    NaN       NaN    4.822501   NaN   NaN  ...    NaN   NaN
# 4                    NaN       NaN    9.679526   NaN   NaN  ...    NaN   NaN
#
#    5100  5110  5111  5120  5121  5200  5300  6000
# ...

# %%
data_df_trimmed.dropna(subset=['Top_1'], inplace=True)

# %%
trim_clean_df = data_df_trimmed.dropna()
print(trim_clean_df.shape)
trim_clean_df.head()
# Out:
# (289, 29)
#       Country  Year   Top_1  Tax_Rev_to_GDP  Individual_Spending_Rate  \
# 87  Australia  2000  0.0821          30.377                 10.687945
# 88  Australia  2001  0.0757          28.890                 10.638735
# 89  Australia  2002  0.0793          29.739                 10.605550
# 90  Australia  2003  0.0812          29.926                 10.742314
# 91  Australia  2004  0.0842          30.258                 10.917760
#
#     Society_Spending_Rate  Top_Rate  GDP_growth    1100   1200  ...   4500  \
# 87               6.890812      48.5    3.943189  11.471  6.152  ...    0.0
# 88               7.065841      48.5    1.933106  11.915  4.349  ...    0.0
# 89               6.817096      48.5    4.003022  11.773  4.949  ...    0.0
# 90               6.580981      48.5    2.985745  11.891  4.960  ...    0.0
# 91               6.653405      48.5    4.001106  12.143  5.468  ...    0.0
#
#     4600   5100   5110   5111   5120   5121   5200  5300  6000
# ...

# %%
X_trim = trim_clean_df.drop(['Country', 'Year', '1100', 'Top_1', '6000'], axis=1)
X_trim.head()
# Out:
#     Tax_Rev_to_GDP  Individual_Spending_Rate  Society_Spending_Rate  Top_Rate  \
# 87          30.377                 10.687945               6.890812      48.5
# 88          28.890                 10.638735               7.065841      48.5
# 89          29.739                 10.605550               6.817096      48.5
# 90          29.926                 10.742314               6.580981      48.5
# 91          30.258                 10.917760               6.653405      48.5
#
#     GDP_growth   1200  1300  2100  2200  2300  ...    4400  4500  4600   5100  \
# 87    3.943189  6.152   0.0   0.0   0.0   0.0  ...   1.381   0.0   0.0  7.957
# 88    1.933106  4.349   0.0   0.0   0.0   0.0  ...   1.282   0.0   0.0  8.012
# 89    4.003022  4.949   0.0   0.0   0.0   0.0  ...   1.372   0.0   0.0  8.271
# 90    2.985745  4.960   0.0   0.0   0.0   0.0  ...   1.496   0.0   0.0  8.115
# 91    4.001106  5.468   0.0   0.0   0.0   0.0  ...   1.260   0.0   0.0  7.879
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_trim, y, test_size=0.3, random_state=42)

# %%
lr = LinearRegression()

# Fit the model against the training data
lr.fit(X_train, y_train)
# Evaluate the model against the testing data
lr.score(X_test, y_test)
# Out:
# 0.6607689976616371

# %%
lasso = linear_model.Lasso(alpha=.0000001, max_iter=100000)

lasso.fit(X_train, y_train)
# Evaluate the model against the testing data
print(lasso.score(X_test, y_test))
# Out:
# 0.6645087558671878
# /Users/bradpanzarella/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# ### Scale and do CV

# %%
std = StandardScaler()
#std.fit(X_train.values.astype(float))
std.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_tr = std.transform(X_train)

X_te = std.transform(X_test)

# %%
lr_model7 = Lasso(alpha = 10000)
lr_model7.fit(X_tr,y_train)
# Out:
# Lasso(alpha=10000, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
lr_model7.score(X_te, y_test)
# Out:
# -0.029862352131365677

# %%
# Run the cross validation, find the best alpha, refit the model on all the data with that alpha

alphavec = 10**np.linspace(-12,1,90)

lr_model8 = LassoCV(alphas = alphavec, cv=5, max_iter=1000000, tol=0.1)
lr_model8.fit(X_tr,y_train)
# Out:
# /Users/bradpanzarella/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/bradpanzarella/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/bradpanzarella/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
lr_model8.alpha_
# Out:
# 5.237223688824736e-06

# %%
# These are the coefficients when it refit using that best alpha
list(zip(X_train.columns,lr_model8.coef_))
# Out:
# [('Tax_Rev_to_GDP', 0.6390739229398718),
#  ('Individual_Spending_Rate', -3.3565459198182404),
#  ('Society_Spending_Rate', 0.4456013786098451),
#  ('Top_Rate', 0.5303708591171409),
#  ('GDP_growth', -0.2537080227047793),
#  ('1200', -0.3337521913866633),
#  ('1300', -0.5609532918141154),
#  ('2100', 0.914006957768652),
#  ('2200', 0.5330335641014489),
#  ('2300', -1.01908174337348),
#  ('2400', -1.2772279035772054),
#  ('4100', 1.3663533998964164),
#  ('4200', -0.20199997538521677),
#  ('4300', -0.6748082613849427),
#  ('4400', 0.03665568802839633),
#  ('4500', 0.02036269890808692),
#  ('4600', 0.5239062590687864),
#  ('5100', 33.52691480390239),
#  ('5110', -22.896824608401175),
#  ('5111', -3.3926180915542385),
#  ('5120', -12.762820382854551),
#  ('5121', 1.9355986974873791),
#  ('5200', -0.46187248241769807),
#  ('5300', -0.7229420161372411)]

# %%
lr_model8.score(X_te, y_test)
# Out:
# 0.6644273146338022

# %%
trim_clean_df.Year.unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016])

# %%
usa_df = data_df_trimmed[data_df_trimmed.Country == 'United States']
usa_df
# Out:
#             Country  Year    Top_1  Tax_Rev_to_GDP  Individual_Spending_Rate  \
# 2549  United States  1966  0.12641          23.767                       NaN
# 2550  United States  1967  0.12145          24.844                       NaN
# 2551  United States  1968  0.12419          24.288                       NaN
# 2552  United States  1969  0.11511          26.606                       NaN
# 2553  United States  1970  0.10793          25.721                  5.795811
# 2554  United States  1971  0.11084          23.869                  6.073088
# 2555  United States  1972  0.11119          24.414                  6.187622
# 2556  United States  1973  0.11019          24.416                  6.069109
# 2557  United States  1974  0.10552          25.151                  6.312618
# 2558  United States  1975  0.10583          24.595                  6.609615
# 2559  United States  1976  0.10406          23.968                  6.398660
# ...

# %%
usa_df = trim_clean_df[trim_clean_df.Country == 'United States']
usa_df.head()
# Out:
#             Country  Year    Top_1  Tax_Rev_to_GDP  Individual_Spending_Rate  \
# 2583  United States  2000  0.18266          28.202                  6.037956
# 2584  United States  2001  0.17268          27.159                  6.265980
# 2585  United States  2002  0.17058          24.942                  6.364184
# 2586  United States  2003  0.17202          24.399                  6.347576
# 2587  United States  2004  0.18322          24.623                  6.269954
#
#       Society_Spending_Rate  Top_Rate  GDP_growth    1100   1200  ...   4500  \
# 2583               7.929256      46.5    4.092176  11.906  2.230  ...    0.0
# 2584               8.386425      45.9    0.975982  11.554  1.567  ...    0.0
# 2585               8.699400      45.2    1.786128   9.490  1.429  ...    0.0
# 2586               8.831678      41.4    2.806776   8.620  1.822  ...    0.0
# 2587              10.162435      41.4    3.785743   8.446  2.231  ...    0.0
#
# ...

# %%
X_usa = usa_df.drop(['Country', 'Year', '1100', 'Top_1', '6000'], axis=1)
X_usa.head()
# Out:
#       Tax_Rev_to_GDP  Individual_Spending_Rate  Society_Spending_Rate  \
# 2548          23.500                       NaN                    NaN
# 2549          23.767                       NaN                    NaN
# 2550          24.844                       NaN                    NaN
# 2551          24.288                       NaN                    NaN
# 2552          26.606                       NaN                    NaN
#
#       Top_Rate  GDP_growth   1200  1300   2100   2200   2300  ...    4400  \
# 2548       NaN         6.4  3.854   0.0  1.190  1.787  0.145  ...   0.023
# 2549       NaN         6.5  4.102   0.0  1.305  1.847  0.118  ...   0.027
# 2550       NaN         2.5  4.312   0.0  1.596  2.114  0.212  ...   0.028
# 2551       NaN         4.8  3.464   0.0  1.585  2.033  0.172  ...   0.046
# 2552       NaN         3.1  4.056   0.0  1.689  2.144  0.175  ...   0.053
#
#       4500  4600   5100   5110  5111   5120   5121   5200  5300
# ...

# %% [markdown]
# ### Try XGBoost

# %%
gbm = xgb.XGBRegressor( 
                       n_estimators=30000, #arbitrary large number
                       max_depth=3,
                       objective="reg:linear",
                       learning_rate=.1, 
                       subsample=1,
                       min_child_weight=1,
                       colsample_bytree=.8
                      )

# %%
X_trim = data_df_trimmed.drop(['Country', 'Year', '1100', 'Top_1', '6000'], axis=1)
X_trim.head()
# Out:
#     Tax_Rev_to_GDP  Individual_Spending_Rate  Society_Spending_Rate  Top_Rate  \
# 32             NaN                       NaN                    NaN       NaN
# 33             NaN                       NaN                    NaN       NaN
# 34             NaN                       NaN                    NaN       NaN
# 35             NaN                       NaN                    NaN       NaN
# 36             NaN                       NaN                    NaN       NaN
#
#     GDP_growth  1200  1300  2100  2200  2300  ...   4400  4500  4600  5100  \
# 32    8.111047   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN
# 33    3.850179   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN
# 34   -3.385457   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN
# 35   -0.788999   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN
# 36   -4.408840   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN
#
#     5110  5111  5120  5121  5200  5300
# ...

# %%
y = data_df_trimmed.Top_1*100
y.head()
# Out:
# 32    12.390000
# 33    12.570000
# 34    13.530000
# 35    14.340000
# 36    12.909999
# Name: Top_1, dtype: float64

# %%
#Split data into 3: 60% train, 20% validation, 20% test
X_train, X_test, y_train, y_test = train_test_split(X_trim, y, test_size=0.2, random_state=2018)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=2019)

# %%
eval_set=[(X_train,y_train),(X_val,y_val)]

# %%
fit_model = gbm.fit( 
                    X_train, y_train, 
                    #eval_set=eval_set,
                    eval_metric='rmse',
                    early_stopping_rounds=50,
                    verbose=True #gives output log as below
                   )
