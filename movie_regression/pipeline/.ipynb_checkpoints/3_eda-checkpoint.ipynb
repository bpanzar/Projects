# %%
import pandas as pd
import pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, LassoCV
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
with open("data/movie_data_smooth.pkl", 'rb') as picklefile: 
    df = pickle.load(picklefile)

# %%
print("The shape of the DataFrame is:", df.shape)
df.head()
# Out:
# The shape of the DataFrame is: (3019, 11)
#              Genre Language  Nudity Rating     Sex  \
# 0           Action   Medium   Light  PG-13    None
# 1         Animated     None   Light     PG    None
# 2         Thriller    Heavy  Medium      R  Medium
# 3  Science Fiction    Heavy   Light  PG-13    None
# 4         Thriller    Heavy    None      R    None
#
#                                    Title Violence Release_Date  \
# 0                             Skyscraper   Medium    7/13/2018
# 1  Hotel Transylvania 3: Summer Vacation    Light    7/13/2018
# 2                        The First Purge    Heavy     7/4/2018
# 3                   Ant-Man And The Wasp   Medium     7/6/2018
# 4            Sicario: Day Of The Soldado    Heavy    6/29/2018
#
#    Production_Budget  Domestic_Gross  Worldwide_Gross
# 0          125000000        31562840         71955649
# 1           65000000        57597439        112373051
# 2           13000000        52929930         76023230
# 3          130000000       142156135        293129020
# 4           35000000        44370869         60095029

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3019 entries, 0 to 3018
# Data columns (total 11 columns):
# Genre                3019 non-null object
# Language             3019 non-null object
# Nudity               3019 non-null object
# Rating               3019 non-null object
# Sex                  3019 non-null object
# Title                3019 non-null object
# Violence             3019 non-null object
# Release_Date         3019 non-null object
# Production_Budget    3019 non-null int64
# Domestic_Gross       3019 non-null int64
# Worldwide_Gross      3019 non-null int64
# dtypes: int64(3), object(8)
# memory usage: 259.5+ KB

# %%
df.describe()
# Out:
#        Production_Budget  Domestic_Gross  Worldwide_Gross
# count       3.019000e+03    3.019000e+03     3.019000e+03
# mean        3.998957e+07    5.317473e+07     1.178972e+08
# std         4.533945e+07    7.425555e+07     1.963899e+08
# min         1.100000e+03    0.000000e+00     0.000000e+00
# 25%         1.000000e+07    7.784598e+06     1.283477e+07
# 50%         2.500000e+07    2.842675e+07     4.766601e+07
# 75%         5.200000e+07    6.647570e+07     1.341739e+08
# max         4.250000e+08    7.605076e+08     2.776345e+09

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                    Production_Budget  Domestic_Gross  Worldwide_Gross
# Production_Budget           1.000000        0.684543         0.747608
# Domestic_Gross              0.684543        1.000000         0.939959
# Worldwide_Gross             0.747608        0.939959         1.000000

# %%
sns.distplot(df['Domestic_Gross'])
# Out:
# /Users/bradpanzarella/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
X = df['Production_Budget']
y = df['Domestic_Gross']

# %%
model = sm.OLS(y,sm.add_constant(X))
results = model.fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Domestic_Gross   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.471
# Method:                 Least Squares   F-statistic:                     2668.
# Date:                Wed, 18 Jul 2018   Prob (F-statistic):               0.00
# Time:                        18:43:04   Log-Likelihood:                -57696.
# No. Observations:                3001   AIC:                         1.154e+05
# Df Residuals:                    2999   BIC:                         1.154e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              8.162e+06   1.32e+06      6.190      0.000    5.58e+06    1.07e+07
# Production_Budget     1.1259      0.022     51.655      0.000       1.083       1.169
# ==============================================================================
# Omnibus:                     1662.140   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21669.600
# Skew:                           2.353   Prob(JB):                         0.00
# Kurtosis:                      15.294   Cond. No.                     8.07e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.07e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_pred = results.predict(sm.add_constant(X))

plt.scatter(y_pred,y-y_pred,alpha=.1)
plt.plot(np.linspace(0,600000,1000),np.linspace(0,0,1000))
plt.xlabel('Predicted Value')
plt.ylabel('Residual')
# Out:
# Text(0,0.5,'Residual')

# %%
df.sort_values('Production_Budget', ascending=False)
# Out:
#                 Genre Language  Nudity                     Rating     Sex  \
# 2934  Science Fiction    Heavy  Medium                      PG-13   Light
# 63    Science Fiction   Medium   Light                      PG-13    None
# 310          Thriller   Medium   Light                      PG-13   Light
# 20    Science Fiction   Medium   Light                      PG-13   Light
# 3019  Science Fiction   Medium   Light                      PG-13    None
# 648           Western   Medium   Light                      PG-13    None
# 723            Action   Medium   Light                      PG-13   Light
# 2794         Animated     None    None                         PG    None
# 2216           Action    Light   Light                      PG-13    None
# 739           Fantasy     None   Light                      PG-13    None
# 119          Thriller    Heavy   Light                      PG-13   Light
# 574            Action     None   Light                      PG-13   Light
# 2646  Science Fiction    Light    None                         PG    None
# 426            Action    Light   Light                      PG-13    None
# 1415           Comedy    Light   Light                      PG-13   Light
# 2399         Thriller   Medium   Light                      PG-13   Light
# 108           Fantasy    Light   Light                      PG-13   Light
# 2447           Action     None   Light                         PG    None
# 657   Science Fiction   Medium   Light                      PG-13    None
# 816            Action    Light   Light                      PG-13    None
# 2174  Science Fiction    Light    None                      PG-13    None
# 364   Science Fiction   Medium    None                      PG-13   Light
# 3008  Science Fiction    Heavy    None                      PG-13    None
# 1424  Science Fiction   Medium   Light                      PG-13   Light
# 499   Science Fiction    Heavy    None                      PG-13    None
# 2860           Action    Light   Light                      PG-13   Light
# 3035  Science Fiction    Heavy   Light                      PG-13   Light
# 22             Horror   Medium   Light                      PG-13    None
# 2365  Science Fiction     None    None                      PG-13   Light
# 2595  Science Fiction    Light   Light                      PG-13    None
# ...               ...      ...     ...                        ...     ...
# 702          Thriller    Heavy  Medium                          R  Medium
# 2348           Horror    Heavy   Heavy                          R   Light
# 2722            Drama    Light    None                      PG-13    None
# 2183            Drama    Heavy   Heavy                          R   Heavy
# 2974  Science Fiction    Light  Medium                      PG-13  Medium
# 148             Drama    Light   Light                  Not Rated   Light
# 1173         Thriller    Heavy  Medium          Not rated by MPAA  Medium
# 2238          Musical    Heavy    None                          R    None
# 1960           Horror    Heavy   Light                          R   Light
# 1912           Comedy    Light    None                         PG   Light
# 1381            Drama     None    None                         PG    None
# 353            Horror    Heavy    None                          R    None
# 807             Drama    Light    None                         PG    None
# 2560         Thriller    Heavy  Medium                          R  Medium
# 2373           Comedy    Heavy  Medium                          R  Medium
# 824          Thriller   Medium    None                          R    None
# 1878      Documentary    Light    None                  Not Rated    None
# 353                                        The Gallows   Medium    7/10/2015
# 807                                         The Mighty    Light    10/9/1998
# 2560                        The Last House On The Left    Heavy    8/30/1972
# 2373                                 The Foot Fist Way    Heavy    5/30/2008
# 824                                                 Pi   Medium    7/10/1998
# 1878                                     Super Size Me    Light     5/7/2004
# 506                                         The Signal   Medium    2/22/2008
# 2762                                    Tiny Furniture    Light   11/12/2010
# 1140                             The Brothers Mcmullen     None     8/9/1995
# 1443                                 George Washington   Medium   10/27/2000
# 1769                                       Funny Ha Ha    Light    4/29/2005
# 1211                                            Clerks     None   10/19/1994
# 1433                                          Flywheel     None   12/31/2003
# 2839                                  Breaking Upwards     None     4/2/2010
# 862                                               Bang     None     4/1/1996
# 3006                                         Newlyweds    Light    1/13/2012
# 931                                        El Mariachi   Medium    2/26/1993
# 1836                                            Primer    Light    10/8/2004
# 1750                                 My Date With Drew     None     8/5/2005
#
#       Production_Budget  Domestic_Gross  Worldwide_Gross
# 2934          425000000       760507625       2776345279
# 63            300000000       229024295        655953446
# 310           300000000       200074175        879620923
# 20            300000000       676245568       2019190029
# 3019          275000000        73058679        282778100
# 648           275000000        89302115        260002115
# 723           275000000       448139099       1084439099
# 2794          260000000       200821936        586477240
# 2216          258000000       336530303        894860230
# 739           250000000       303003568       1017003568
# 119           250000000       225764765       1237466026
# 574           250000000       258366855        960366855
# 2646          250000000       301959197        935083686
# 426           250000000       255119788        955119788
# 1415          232000000       200120000        374085065
# 2399          230000000       169368427        591692078
# 108           230000000       172558876        790094284
# 2447          225000000       141621490        417341288
# 657           225000000       291045518        667999518
# 816           225000000       623279547       1519479547
# 2174          220000000       262030663        757890267
# 364           215000000       652270625       1671713208
# 3008          215000000       179020854        654213485
# 1424          210000000       234362462        459260946
# 499           210000000       245439076       1104039076
# 2860          210000000       105487148        322459006
# 3035          209000000        65233400        305218228
# 22            207000000       218080025        550517357
# 2365          205000000        70107728        367262558
# 2595          200000000       125322469        365491792
# ...                 ...             ...              ...
# 702              200000           44701            44701
# 2348             200000          140016           140016
# 2722             200000         2430735          2430735
# 2183             190000          484592          1577585
# 2974             175000         1321194          2102779
# 148              170000          166425           169242
# 1173             150000          110719           110719
# 2238             150000         9445857         23324057
# 1960             140000        26572439         26572439
# 1912             100000          110536           110536
# 1381             100000        10178331         10243159
# 353              100000        22764410         41753881
# 807              100000         2652246          6121582
# 2560              87000         3100000          3100000
# 2373              79000          234286           234286
# 824               68000         3221152          4678513
# 1878              65000        11529368         22233808
# 506               50000          251150           406299
# 2762              50000          391674           424149
# 1140              50000        10426506         10426506
# 1443              42000          241816           342722
# 1769              30000           77070            82698
# 1211              27000         3073428          3894240
# 1433              20000               0                0
# 2839              15000          115592           115592
# 862               10000             527              527
# 3006               9000            4584             4584
# 931                7000         2040920          2041928
# 1836               7000          424760           841926
# 1750               1100          181041           181041
#
# [3001 rows x 11 columns]
