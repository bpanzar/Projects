# %%
import pandas as pd
import nltk
import string
import pickle

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

from sklearn.naive_bayes import MultinomialNB

# %%
df = pd.read_csv('data/IRAhandle_tweets_1.csv')

# %%
df.shape
# Out:
# (381016, 15)

# %%
df.head()
# Out:
#    external_author_id  author  \
# 0        9.060000e+17  10_GOP
# 1        9.060000e+17  10_GOP
# 2        9.060000e+17  10_GOP
# 3        9.060000e+17  10_GOP
# 4        9.060000e+17  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#       publish_date   harvested_date  following  followers  updates post_type  \
# 0  10/1/2017 19:58  10/1/2017 19:59       1052       9636      253       NaN
# 1  10/1/2017 22:43  10/1/2017 22:43       1054       9637      254       NaN
# 2  10/1/2017 22:50  10/1/2017 22:51       1054       9637      255   RETWEET
# 3  10/1/2017 23:52  10/1/2017 23:52       1062       9642      256       NaN
# 4   10/1/2017 2:13   10/1/2017 2:13       1050       9645      246   RETWEET
#
#   account_type  new_june_2018  retweet account_category
# 0        Right              0        0       RightTroll
# 1        Right              0        0       RightTroll
# 2        Right              0        1       RightTroll
# 3        Right              0        0       RightTroll
# 4        Right              0        1       RightTroll

# %%
df['account_category'].unique()
# Out:
# array(['RightTroll', 'NonEnglish', 'Fearmonger', 'LeftTroll', 'Unknown',
#        'HashtagGamer', 'NewsFeed', 'Commercial'], dtype=object)

# %%
df[df['account_category']=='NewsFeed']
# Out:
#         external_author_id           author  \
# 52727         8.026730e+17    ALBUQUERQUEON
# 52728         8.026730e+17    ALBUQUERQUEON
# 52729         8.026730e+17    ALBUQUERQUEON
# 52730         8.026730e+17    ALBUQUERQUEON
# 52731         8.026730e+17    ALBUQUERQUEON
# 52732         8.026730e+17    ALBUQUERQUEON
# 52733         8.026730e+17    ALBUQUERQUEON
# 52734         8.026730e+17    ALBUQUERQUEON
# 52735         8.026730e+17    ALBUQUERQUEON
# 52736         8.026730e+17    ALBUQUERQUEON
# 52737         8.026730e+17    ALBUQUERQUEON
# 52738         8.026730e+17    ALBUQUERQUEON
# 52739         8.026730e+17    ALBUQUERQUEON
# 52740         8.026730e+17    ALBUQUERQUEON
# 52741         8.026730e+17    ALBUQUERQUEON
# 52742         8.026730e+17    ALBUQUERQUEON
# 52743         8.026730e+17    ALBUQUERQUEON
# 52744         8.026730e+17    ALBUQUERQUEON
# 52745         8.026730e+17    ALBUQUERQUEON
# 52746         8.026730e+17    ALBUQUERQUEON
# 52747         8.026730e+17    ALBUQUERQUEON
# 52748         8.026730e+17    ALBUQUERQUEON
# 52749         8.026730e+17    ALBUQUERQUEON
# 52750         8.026730e+17    ALBUQUERQUEON
# 52751         8.026730e+17    ALBUQUERQUEON
# 52752         8.026730e+17    ALBUQUERQUEON
# 52753         8.026730e+17    ALBUQUERQUEON
# 52754         8.026730e+17    ALBUQUERQUEON
# 52755         8.026730e+17    ALBUQUERQUEON
# 52756         8.026730e+17    ALBUQUERQUEON
# ...                    ...              ...
# 284660        3.091979e+09  BATONROUGEVOICE
# 284661        3.091979e+09  BATONROUGEVOICE
# 284662        3.091979e+09  BATONROUGEVOICE
# 284663        3.091979e+09  BATONROUGEVOICE
# 284664        3.091979e+09  BATONROUGEVOICE
# 284665        3.091979e+09  BATONROUGEVOICE
# 284666        3.091979e+09  BATONROUGEVOICE
# 284667        3.091979e+09  BATONROUGEVOICE
# 284668        3.091979e+09  BATONROUGEVOICE
# 284669        3.091979e+09  BATONROUGEVOICE
# 284670        3.091979e+09  BATONROUGEVOICE
# 284671        3.091979e+09  BATONROUGEVOICE
# 284672        3.091979e+09  BATONROUGEVOICE
# 284673        3.091979e+09  BATONROUGEVOICE
# 284674        3.091979e+09  BATONROUGEVOICE
# 284675        3.091979e+09  BATONROUGEVOICE
# 284676        3.091979e+09  BATONROUGEVOICE
# 284677        3.091979e+09  BATONROUGEVOICE
# 284678        3.091979e+09  BATONROUGEVOICE
# 284679        3.091979e+09  BATONROUGEVOICE
# 284680        3.091979e+09  BATONROUGEVOICE
# 284681        3.091979e+09  BATONROUGEVOICE
# 284682        3.091979e+09  BATONROUGEVOICE
# 284683        3.091979e+09  BATONROUGEVOICE
# 284684        3.091979e+09  BATONROUGEVOICE
# 284685        3.091979e+09  BATONROUGEVOICE
# 284686        3.091979e+09  BATONROUGEVOICE
# 284687        3.091979e+09  BATONROUGEVOICE
# 284688        3.091979e+09  BATONROUGEVOICE
# 284689        3.091979e+09  BATONROUGEVOICE
#
#                                                   content         region  \
# 52727   Albuquerque men arrested for trying to sell st...        Unknown
# 52728   Albuquerque Pokemon Go players here to stay an...        Unknown
# 52729   Queen Elizabeth II misses church due to 'heavy...        Unknown
# 52730   New UN chief urges New Year's resolution: 'Put...        Unknown
# 52731   China says it will shut down ivory trade by en...        Unknown
# 52732   Rural New Mexico exports mentoring model for p...        Unknown
# 52733   County enters last weekend of Tavern Taxi prog...        Unknown
# 52734   Eye on New Mexico: Water in New Mexico https:/...        Unknown
# 52735   Family searching for missing woman from Cubero...        Unknown
# 52736   New Year’s Eve weather forecast https://t.co/9...        Unknown
# 52737   Repeat offender attempting to steal a truck in...        Unknown
# 52738   Rain dampens world record Menorah attempt http...        Unknown
# 52739   City celebrates NYE in Civic Plaza https://t.c...        Unknown
# 52740   State police crack down on drunk drivers durin...        Unknown
# 52741   Albuquerque mayor revives Commission on Indian...        Unknown
# 52742   Energy boss: Nuke-leak progress but work ahead...        Unknown
# 52743   Woman steals purses at 2 Albuquerque churches ...        Unknown
# 52744   Reports: gunfire heard near police station in ...        Unknown
# 52745   Company to add 70 manufacturing jobs in Roswel...        Unknown
# 52746   New Mexico Democrats to watch Obama's 'farewel...        Unknown
# 52747   Tuesday morning weather forecast https://t.co/...        Unknown
# 52748   OMI releases autopsy report of slain Albuquerq...        Unknown
# 52749   Woman’s remains spark questions among Santa An...        Unknown
# 52750   New Mexico Highlands University has named a ne...        Unknown
#
#         updates post_type account_type  new_june_2018  retweet  \
# 52727       822       NaN        local              1        0
# 52728       830       NaN        local              1        0
# 52729       831       NaN        local              1        0
# 52730       832       NaN        local              1        0
# 52731       833       NaN        local              1        0
# 52732       834       NaN        local              1        0
# 52733       823       NaN        local              1        0
# 52734       835       NaN        local              1        0
# 52735       824       NaN        local              1        0
# 52736       825       NaN        local              1        0
# 52737       826       NaN        local              1        0
# 52738       827       NaN        local              1        0
# 52739       828       NaN        local              1        0
# 52740       829       NaN        local              1        0
# 52741      1051       NaN        local              1        0
# 52742      1052       NaN        local              1        0
# 52743      1053       NaN        local              1        0
# 52744      1062       NaN        local              1        0
# 52745      1063       NaN        local              1        0
# 52746      1064       NaN        local              1        0
# 52747      1065       NaN        local              1        0
# 52748      1066       NaN        local              1        0
# 52749      1067       NaN        local              1        0
# 52750      1068       NaN        local              1        0
# 52751      1069       NaN        local              1        0
# 52752      1070       NaN        local              1        0
# 52753      1071       NaN        local              1        0
# 52754      1072       NaN        local              1        0
# 52755      1054       NaN        local              1        0
# 52756      1055       NaN        local              1        0
# ...         ...       ...          ...            ...      ...
# 284660    19334       NaN        local              0        0
# 284661    19335       NaN        local              0        0
# 284662    19336       NaN        local              0        0
# 284663    19337       NaN        local              0        0
# 284664    19338       NaN        local              0        0
# 284665    19339       NaN        local              0        0
# 284666    19340       NaN        local              0        0
# 284667    19341       NaN        local              0        0
# 284668    19302       NaN        local              0        0
# 284669    19342       NaN        local              0        0
# 284670    19343       NaN        local              0        0
# 284671    19344       NaN        local              0        0
# 284672    19346       NaN        local              0        0
# 284673    19345       NaN        local              0        0
# 284674    19347       NaN        local              0        0
# 284675    19348       NaN        local              0        0
# 284676    19349       NaN        local              0        0
# 284677    19303       NaN        local              0        0
# 284678    19304       NaN        local              0        0
# 284679    19305       NaN        local              0        0
# 284680    19306       NaN        local              0        0
# 284681    19307       NaN        local              0        0
# 284682    19308       NaN        local              0        0
# 284683    19309       NaN        local              0        0
# 284684    19310       NaN        local              0        0
# 284685    19311       NaN        local              0        0
# 284686    19312       NaN        local              0        0
# 284687    19313       NaN        local              0        0
# 284688    19314       NaN        local              0        0
# 284689    19315       NaN        local              0        0
#
#        account_category
# 52727          NewsFeed
# 52728          NewsFeed
# 52729          NewsFeed
# 52730          NewsFeed
# 52731          NewsFeed
# 52732          NewsFeed
# 52733          NewsFeed
# 52734          NewsFeed
# 52735          NewsFeed
# 52736          NewsFeed
# 52737          NewsFeed
# 52738          NewsFeed
# 52739          NewsFeed
# 52740          NewsFeed
# 52741          NewsFeed
# 52742          NewsFeed
# 52743          NewsFeed
# 52744          NewsFeed
# 52745          NewsFeed
# 52746          NewsFeed
# 52747          NewsFeed
# 52748          NewsFeed
# 52749          NewsFeed
# 52750          NewsFeed
# 52751          NewsFeed
# 52752          NewsFeed
# 52753          NewsFeed
# 52754          NewsFeed
# 52755          NewsFeed
# 52756          NewsFeed
# ...                 ...
# 284660         NewsFeed
# 284661         NewsFeed
# 284662         NewsFeed
# 284663         NewsFeed
# 284664         NewsFeed
# 284665         NewsFeed
# 284666         NewsFeed
# 284667         NewsFeed
# 284668         NewsFeed
# 284669         NewsFeed
# 284670         NewsFeed
# 284671         NewsFeed
# 284672         NewsFeed
# 284673         NewsFeed
# 284674         NewsFeed
# 284675         NewsFeed
# 284676         NewsFeed
# 284677         NewsFeed
# 284678         NewsFeed
# 284679         NewsFeed
# 284680         NewsFeed
# 284681         NewsFeed
# 284682         NewsFeed
# 284683         NewsFeed
# 284684         NewsFeed
# 284685         NewsFeed
# 284686         NewsFeed
# 284687         NewsFeed
# 284688         NewsFeed
# 284689         NewsFeed
#
# [32423 rows x 15 columns]

# %%
df_english = df[df['account_category'] != 'NonEnglish']

# %%
df_english.shape
# Out:
# (292080, 15)

# %%
def custom_tokenizer(text):
    punc = ''.join(string.punctuation.split('#'))
    
    # remove punctuation
    remove_punct = str.maketrans('', '', punc)
    text = text.translate(remove_punct)

    # remove digits and convert to lower case
    remove_digits = str.maketrans('', '', string.digits)
    text = text.lower().translate(remove_digits)

    # tokenize
    tokens = word_tokenize(text)

    # remove stop words
    stop_words = stopwords.words('english')
    tokens_stop = [y for y in tokens if y not in stop_words]

    # stem
    stemmer = SnowballStemmer('english')
    tokens_stem = [stemmer.stem(y) for y in tokens_stop] 

    return tokens_stem

# %%
cv = CountVectorizer(tokenizer=custom_tokenizer)

# %%
test_df = df_english[0:10000]

# %%
print(test_df.shape)
test_df.head()
# Out:
# (10000, 15)
#    external_author_id  author  \
# 0        9.060000e+17  10_GOP
# 1        9.060000e+17  10_GOP
# 2        9.060000e+17  10_GOP
# 3        9.060000e+17  10_GOP
# 4        9.060000e+17  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#       publish_date   harvested_date  following  followers  updates post_type  \
# 0  10/1/2017 19:58  10/1/2017 19:59       1052       9636      253       NaN
# 1  10/1/2017 22:43  10/1/2017 22:43       1054       9637      254       NaN
# 2  10/1/2017 22:50  10/1/2017 22:51       1054       9637      255   RETWEET
# 3  10/1/2017 23:52  10/1/2017 23:52       1062       9642      256       NaN
# 4   10/1/2017 2:13   10/1/2017 2:13       1050       9645      246   RETWEET
#
#   account_type  new_june_2018  retweet account_category
# 0        Right              0        0       RightTroll
# 1        Right              0        0       RightTroll
# 2        Right              0        1       RightTroll
# 3        Right              0        0       RightTroll
# 4        Right              0        1       RightTroll

# %%
X, y = test_df.content, test_df.account_category
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.3, random_state=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e3db6b267eed> in <module>()
# ----> 1 X, y = test_df.content, test_df.account_category
#       2 X_train, X_test, y_train, y_test =     train_test_split(X, y, test_size=.3, random_state=3)
#
# NameError: name 'test_df' is not defined

# %%
X_train.shape, y_train.shape
# Out:
# ((7000,), (7000,))

# %%
X_test.shape, y_test.shape
# Out:
# ((3000,), (3000,))

# %%
# countvectorizing and training
cv = CountVectorizer(tokenizer=custom_tokenizer)

X_train_cv = cv.fit_transform(X_train)
X_test_cv  = cv.transform(X_test)

# %%
nb = MultinomialNB()

nb.fit(X_train_cv, y_train)
nb.score(X_test_cv, y_test)
#Model with 10,000 tweets, dropping hashtags
# Out:
# 0.823

# %%
X, y = df_english.content, df_english.account_category
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.3, random_state=3)

# %%
X_train.shape, y_train.shape
# Out:
# ((204456,), (204456,))

# %%
# countvectorizing and training
cv = CountVectorizer(tokenizer=custom_tokenizer)

X_train_cv = cv.fit_transform(X_train)
X_test_cv  = cv.transform(X_test)

# %%
nb = MultinomialNB()

nb.fit(X_train_cv, y_train)
nb.score(X_test_cv, y_test)
#Model with all tweets, dropping hashtags

# %%
preds = nb.predict(X_test_cv)

# %%
X_test.head(10)

# %%
y_test.head(10)

# %%
print(preds[:10])

# %%
X_test.iloc[1]

# %%
X, y = df_english.content, df_english.account_category
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.3, random_state=3)

# countvectorizing and training
cv = CountVectorizer(tokenizer=custom_tokenizer)

X_train_cv = cv.fit_transform(X_train)  
X_test_cv  = cv.transform(X_test)

# %%
nb = MultinomialNB()

nb.fit(X_train_cv, y_train)
nb.score(X_test_cv, y_test)
#Model with all tweets, keeping hashtags
# Out:
# 0.7975554642563681

# %%
with open('nb_model.pkl', 'wb') as picklefile:
    pickle.dump(nb, picklefile)

# %%
with open('nb_model.pkl', 'rb') as picklefile:
    nb_model = pickle.load(picklefile)

# %%
nb_model.predict(X_test_cv[0])
# Out:
# array(['NewsFeed'], dtype='<U12')

# %%
mytweet = 'Florida man feeds food to alligator'
#tokens = custom_tokenizer(mytweet)
tokens_cv = cv.transform([mytweet])
nb.predict(tokens_cv)[0]
# for word in tokens:
#     print(word)
#     print(nb.predict(cv.transform([word])))
# Out:
# 'NewsFeed'

# %%
def russiafy_my_tweet(tweet):
    tokens_cv = cv.transform([tweet])
    print('Your tweet is most similar to a Russian', nb.predict(tokens_cv)[0])

# %%
russiafy_my_tweet('Florida man feeds food to alligator')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d54ef684b773> in <module>()
# ----> 1 russiafy_my_tweet('Florida man feeds food to alligator')
#
# <ipython-input-4-2a00ef45f34d> in russiafy_my_tweet(tweet)
#       1 def russiafy_my_tweet(tweet):
# ----> 2     tokens_cv = cv.transform([tweet])
#       3     print('Your tweet is most similar to a Russian', nb.predict(tokens_cv)[0])
#
# NameError: name 'cv' is not defined

# %%
russiafy_my_tweet('Trump is the best forever, #MAGA')
# Out:
# Your tweet is most similar to a Russian RightTroll

# %%
russiafy_my_tweet('Why do cops hate people')
# Out:
# Your tweet is most similar to a Russian LeftTroll

# %% [markdown]
# ### Now lets try with 2 grams

# %%
X, y = df_english.content, df_english.account_category
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.3, random_state=3)

# countvectorizing and training
cv = CountVectorizer(tokenizer=custom_tokenizer, ngram_range=(1,2))

X_train_cv = cv.fit_transform(X_train)
X_test_cv  = cv.transform(X_test)

# %%
nb = MultinomialNB()

nb.fit(X_train_cv, y_train)
nb.score(X_test_cv, y_test)
#Model with 2 grams
# Out:
# 0.8213274901853373
