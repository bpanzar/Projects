# %%
import pandas as pd
import numpy as np
import pickle
import nltk

from datetime import datetime

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

# sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
def custom_tokenizer(text):
    full_punc = '’‘“”.–…�🇺🇸★➠' + string.punctuation
    # remove punctuation
    remove_punct = str.maketrans('', '', full_punc)
    text = text.translate(remove_punct)

    # remove digits and convert to lower case
    remove_digits = str.maketrans('', '', string.digits)
    text = text.lower().translate(remove_digits)

    # tokenize
    tokens = word_tokenize(text)

    # remove stop words
    punc = [str(i) for i in string.punctuation]
    cust_stop_words = (['rt', 'retweet', 'get', 'one', 'im', 'thing', 'get', 'dont', 'wow',
                       'lol', 'amp', 'n', 'didnt', 'people', 'like', 'want', 'know', 'go',
                        'think', 'need', 'right', 'good', 'would', 'going', 'never', 'see',
                        'time', 'call', 'said', 'got', 'us', 'p', 'look', 'mr'])
    stop_words = cust_stop_words + stopwords.words('english')
    tokens_stop = [y for y in tokens if y not in stop_words]

    # stem
#    stemmer = SnowballStemmer('english')
#    tokens_stem = [stemmer.stem(y) for y in tokens_stop] 

    return tokens_stop

# %%
with open("rtrolls_df.pkl", 'rb') as picklefile:
    df_rtrolls = pickle.load(picklefile)    
    
import json
with open('topics2words.json', 'r') as fp:
    topic_dict = json.load(fp)

# %%
df_rtrolls.head()
# Out:
#    author                                            content   region  \
# 0  10_GOP  "We have a sitting Democrat US Senator on tria...  Unknown
# 1  10_GOP  Marshawn Lynch arrives to game in anti-Trump s...  Unknown
# 2  10_GOP  Daughter of fallen Navy Sailor delivers powerf...  Unknown
# 3  10_GOP  JUST IN: President Trump dedicates Presidents ...  Unknown
# 4  10_GOP  19,000 RESPECTING our National Anthem! #StandF...  Unknown
#
#   language  following  followers  updates  retweet account_category  \
# 0  English       1052       9636      253        0       RightTroll
# 1  English       1054       9637      254        0       RightTroll
# 2  English       1054       9637      255        1       RightTroll
# 3  English       1062       9642      256        0       RightTroll
# 4  English       1050       9645      246        1       RightTroll
#
#          date  hour  day  topicnumber  strengthoftopic  week
# 0  2017-10-01    19    6            9         0.020203   143
# 1  2017-10-01    22    6            7         0.002535   143
# 2  2017-10-01    22    6           12         0.000442   143
# 3  2017-10-01    23    6            1         0.014205   143
# 4  2017-10-01     2    6            3         0.001020   143

# %%
#group by week
temp_df = df_rtrolls.groupby(["week", "topicnumber"]).count().reset_index()
# temp_df

topic_weeks_df = temp_df[['week', 'topicnumber', 'content']]
# topic_weeks_df

# %%
temp_df = topic_weeks_df[((topic_weeks_df['topicnumber'] == 0) |
        (topic_weeks_df['topicnumber'] == 15) |
        (topic_weeks_df['topicnumber'] == 2) | 
        (topic_weeks_df['topicnumber'] == 4) |
        (topic_weeks_df['topicnumber'] == 19) |
        (topic_weeks_df['topicnumber'] == 11) |     
        (topic_weeks_df['topicnumber'] == 16) |               
        (topic_weeks_df['topicnumber'] == 7) |
        (topic_weeks_df['topicnumber'] == 5) |               
        (topic_weeks_df['topicnumber'] == 13))]

# %%
data_fillna = temp_df.pivot_table('content', 'week', 'topicnumber').fillna(0).unstack().reset_index()

# %%
data_fillna.head()
# Out:
#    topicnumber  week     0
# 0            0     8  23.0
# 1            0    10   0.0
# 2            0    11   1.0
# 3            0    12   7.0
# 4            0    14   3.0

# %%
#we lose the count label column in the previous steps, so we're just renaming it here, and reordering columns based on 
#how they are arranged in the viz csv
data_fillna.columns = ["topicnumber", "week", "content"]
data_fillna = data_fillna[["week", "topicnumber", "content"]]
data_fillna.head()
# Out:
#    week  topicnumber  content
# 0     8            0     23.0
# 1    10            0      0.0
# 2    11            0      1.0
# 3    12            0      7.0
# 4    14            0      3.0

# %%
data_fillna.sort_values('week', inplace=True)

# %%
#backup file
data_fillna.to_csv("topicsbyweek.csv", index = False)

# %%
df_rtrolls[df_rtrolls['week'] == 143]
# Out:
#            author                                            content   region  \
# 0          10_GOP  "We have a sitting Democrat US Senator on tria...  Unknown
# 1          10_GOP  Marshawn Lynch arrives to game in anti-Trump s...  Unknown
# 2          10_GOP  Daughter of fallen Navy Sailor delivers powerf...  Unknown
# 3          10_GOP  JUST IN: President Trump dedicates Presidents ...  Unknown
# 4          10_GOP  19,000 RESPECTING our National Anthem! #StandF...  Unknown
# 5          10_GOP  Dan Bongino: "Nobody trolls liberals better th...  Unknown
# 6          10_GOP  '@SenatorMenendez @CarmenYulinCruz Doesn't mat...  Unknown
# 7          10_GOP  As much as I hate promoting CNN article, here ...  Unknown
# 8          10_GOP  After the 'genocide' remark from San Juan Mayo...  Unknown
# 9          10_GOP  After the 'genocide' remark from San Juan Mayo...  Unknown
# 10         10_GOP  '@thehill Why won't she apologize to us for ly...  Unknown
# 274        10_GOP  Marine veteran Rodney Heard burned $4,000 wort...  Unknown
# 275        10_GOP  "We want more products proudly stamped with th...  Unknown
# 276        10_GOP  BREAKING: Police respond to reports of shooter...  Unknown
# 277        10_GOP  UPDATE: 1 person confirmed dead in Falls Churc...  Unknown
# 278        10_GOP  It starts with the confederate flag. Then the ...  Unknown
# 279        10_GOP  '@realDonaldTrump We Stand for the Flag! #WeSt...  Unknown
# 280        10_GOP  Same author, 6 days apart. His views only chan...  Unknown
# 281        10_GOP  Amazing. We’ve gone from “Trump is Putin's pup...  Unknown
# 282        10_GOP  We’ve gone from “Trump is Putin's puppet” to “...  Unknown
# 283        10_GOP  President Trump: "You cannot have people disre...  Unknown
# 284        10_GOP  CNN's Ana Navarro  is spreading a photoshopped...  Unknown
# 285        10_GOP      '@realDonaldTrump We love you Mr. President!'  Unknown
# 286        10_GOP  '@realDonaldTrump Thank you and your family fo...  Unknown
# 287        10_GOP  '@realDonaldTrump We desperately need #TaxRefo...  Unknown
# 288        10_GOP  Chicago teacher places flag on the ground for ...  Unknown
# 289        10_GOP  '@realDonaldTrump Don't worry, the silent majo...  Unknown
# 290        10_GOP  Daughter of fallen Navy Sailor delivers powerf...  Unknown
# 291        10_GOP                      America is with you patriot!   Unknown
# 292        10_GOP  BREAKING: Playboy founder Hugh Hefner has died...  Unknown
# ...           ...                                                ...      ...
# 1      English       1054       9637      254        0       RightTroll
# 2      English       1054       9637      255        1       RightTroll
# 3      English       1062       9642      256        0       RightTroll
# 4      English       1050       9645      246        1       RightTroll
# 5      English       1050       9644      247        0       RightTroll
# 6      English       1050       9644      249        0       RightTroll
# 7      English       1050       9646      250        0       RightTroll
# 8      English       1050       9646      251        0       RightTroll
# 9      English       1050       9646      251        0       RightTroll
# 10     English       1050       9645      252        0       RightTroll
# 274    English       1034       9049      205        0       RightTroll
# 275    English       1034       9048      206        0       RightTroll
# 276    English       1038       9053      207        0       RightTroll
# 277    English       1039       9055      208        0       RightTroll
# 278    English       1039       9055      209        0       RightTroll
# 279    English       1042       9094      210        1       RightTroll
# 280    English       1042       9098      211        1       RightTroll
# 281    English       1043       9112      212        0       RightTroll
# 282    English       1043       9113      212        0       RightTroll
# 283    English       1044       9129      213        0       RightTroll
# 284    English       1045       9134      214        1       RightTroll
# 285    English       1049       9142      215        0       RightTroll
# 286    English       1049       9143      216        0       RightTroll
# 287    English       1049       9144      217        0       RightTroll
# 288    English       1051       9399      224        0       RightTroll
# 289    English       1049       9145      218        0       RightTroll
# 290    English       1050       9165      219        0       RightTroll
# 291    English       1050       9164      220        0       RightTroll
# 292    English       1052       9178      221        0       RightTroll
# ...        ...        ...        ...      ...      ...              ...
# 68976  English       4915       1959     3392        0       RightTroll
# 68977  English       4915       1959     3401        0       RightTroll
# 68978  English       4915       1959     3403        0       RightTroll
# 68979  English       4915       1959     3402        0       RightTroll
# 68980  English       4915       1959     3398        0       RightTroll
# 68981  English       4915       1959     3399        0       RightTroll
# 68982  English       4915       1959     3400        0       RightTroll
# 68983  English       4915       1959     3394        0       RightTroll
# 68984  English       4915       1959     3393        0       RightTroll
# 68985  English       4915       1959     3396        0       RightTroll
# 68986  English       4915       1959     3395        0       RightTroll
# 68987  English       4916       1963     3429        0       RightTroll
# 68988  English       4916       1963     3430        0       RightTroll
# 68989  English       4916       1963     3428        0       RightTroll
# 68990  English       4916       1963     3431        0       RightTroll
# 68991  English       4916       1963     3432        0       RightTroll
# 68992  English       4916       1963     3434        0       RightTroll
# 68993  English       4916       1963     3433        0       RightTroll
# 68994  English       4916       1964     3436        0       RightTroll
# 68995  Spanish       4916       1964     3435        0       RightTroll
# 68996  English       4916       1964     3437        0       RightTroll
# 68997  English       4916       1964     3438        0       RightTroll
# 68998  English       4916       1964     3439        0       RightTroll
# 68999  English       4916       1964     3441        0       RightTroll
# 69000  English       4916       1964     3440        0       RightTroll
# 69001  English       4915       1959     3406        0       RightTroll
# 69002  English       4915       1959     3407        0       RightTroll
# 69003  English       4915       1959     3405        0       RightTroll
# 69004  English       4915       1959     3408        0       RightTroll
# 69005  English       4915       1959     3404        0       RightTroll
#
#              date  hour  day  topicnumber  strengthoftopic  week
# 0      2017-10-01    19    6            9         0.020203   143
# 1      2017-10-01    22    6            7         0.002535   143
# 2      2017-10-01    22    6           12         0.000442   143
# 3      2017-10-01    23    6            1         0.014205   143
